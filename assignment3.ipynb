# %%
# dictionary

dict = {
"name" : "Tashu Gupta",
"rollno" : 123 ,
"age" : 20,
"city" : "Delhi",
"clg" : "SKIT"

}

print(dict)

print(dict["name"])
print(dict["rollno"])

print(dict.keys())
print(dict.values())
print(dict.items())

print(len(dict))

dict["age"] = 21
print(dict)

dict["country"] = "India"
print(dict)

print(dict.update({"state" : "Rajasthan"}))
print(dict.pop("age"))
print(dict)

print(dict.popitem())
print(dict)
# Out:
# {'name': 'Tashu Gupta', 'rollno': 123, 'age': 20, 'city': 'Delhi', 'clg': 'SKIT'}
# Tashu Gupta
# 123
# dict_keys(['name', 'rollno', 'age', 'city', 'clg'])
# dict_values(['Tashu Gupta', 123, 20, 'Delhi', 'SKIT'])
# dict_items([('name', 'Tashu Gupta'), ('rollno', 123), ('age', 20), ('city', 'Delhi'), ('clg', 'SKIT')])
# 5
# {'name': 'Tashu Gupta', 'rollno': 123, 'age': 21, 'city': 'Delhi', 'clg': 'SKIT'}
# {'name': 'Tashu Gupta', 'rollno': 123, 'age': 21, 'city': 'Delhi', 'clg': 'SKIT', 'country': 'India'}
# None
# 21
# {'name': 'Tashu Gupta', 'rollno': 123, 'city': 'Delhi', 'clg': 'SKIT', 'country': 'India', 'state': 'Rajasthan'}
# ('state', 'Rajasthan')
# {'name': 'Tashu Gupta', 'rollno': 123, 'city': 'Delhi', 'clg': 'SKIT', 'country': 'India'}

# %%
def math_operation(a, b, choice):

    if choice == '+':
        return a + b

    elif choice == '-':
        return a - b

    elif choice == '*':
        return a * b

    elif choice == '/':
        if b != 0:
            return a / b
        else:
            return "Division not possible"

    else:
        return "Invalid Operation"


num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))

op = input("Enter operation (+, -, *, /) : ")

result = math_operation(num1, num2, op)

print("Result =", result)
# Out:
# Result = 11

# %%
#3) Write a program to check Palindrome Number For example Number 12321 is a Palindrome Number, because 12321 is equal to its reverse Number 12321. Steps for checking Palindrome number
 

n = int(input("enter a number : "))

temp =n 
rev =0
while n>0:
    r = n % 10
    rev = rev * 10 + r
    n = n // 10

if rev == temp:
    print("Palindrome Number")
else:    
    print("Not a Palindrome Number")
# Out:
# Not a Palindrome Number
