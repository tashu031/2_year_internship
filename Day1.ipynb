# %%
print("hello world")
# Out:
# hello world

# %%
# this is my first code in python
print("""Hello 
    
      """)
a = 10
a = "this is my first code in python"
print(a, type(a))
# Out:
# Hello
#
#
# this is my first code in python <class 'str'>

# %%
a = 24       # address return by id() is the memory address of the variable a
print( id(a))
b = int(24.0)
print(id(b))
# Out:
# 140728258127496
# 140728258127496

# %%
n1 = int(input("enter a number: "))
print(n1, type(n1))
# Out:
# 7678 <class 'int'>
